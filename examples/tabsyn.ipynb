# %%
# Imports
import sys
from pathlib import Path

# Resolve project root and ensure it's on sys.path
ROOT = Path.cwd().resolve()
for _ in range(5):
    if (ROOT / "pyproject.toml").exists() or (ROOT / "raw_data").exists():
        break
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from utils import discretize_preprocess

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "car.csv"
output_path = ROOT / "discretized_data" / "car.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))
# Out:
# Preprocessing: /Users/vikumdabare/Documents/Work/Katabatic/katabatic/raw_data/car.csv
# Saved preprocessed discrete dataset to: /Users/vikumdabare/Documents/Work/Katabatic/katabatic/discretized_data/car.csv

# %%
from katabatic.models.tabsyn.models import TabSyn
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline


# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "car")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "car" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
)
print(result)
# Out:
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# [TabSyn] Synthetic data saved:
#   X -> /Users/vikumdabare/Documents/Work/Katabatic/katabatic/synthetic/car/tabsyn/x_synth.csv
#   y -> /Users/vikumdabare/Documents/Work/Katabatic/katabatic/synthetic/car/tabsyn/y_synth.csv
# /Users/vikumdabare/Documents/Work/Katabatic/katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/vikumdabare/Documents/Work/Katabatic/katabatic/.venv/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [23:41:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/car/tabsyn_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6012
# F1 Score: 0.5880
#
# MLP:
# Accuracy: 0.4538
# F1 Score: 0.4832
#
# RF:
# Accuracy: 0.3410
# F1 Score: 0.4043
#
# XGBoost:
# Accuracy: 0.2919
# F1 Score: 0.3539
# Train test split pipeline executed successfully.
